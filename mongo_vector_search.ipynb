# %%
DB_NAME = "blogdb"
COLLECTION_NAME = "ai_news"

VECTOR_INDEX_NAME = "title_body_vector_index"
EMBEDDING_FIELD = "title_body_embedding"

# %%
from dotenv import load_dotenv
import os
import pymongo


load_dotenv()
# connect to your Atlas cluster
mongo_client = pymongo.MongoClient(os.getenv("MONGODB_URI"))

db = mongo_client["blogdb"]

collection = db["ai_news"]

article = collection.find_one()

print("Here's an example article (without the embedding):")
{k: v for k, v in article.items() if k != EMBEDDING_FIELD}  # type:ignore
# Out:
# Here's an example article (without the embedding):
# {'_id': ObjectId('667d1ef6fc45eb48396a6a0c'),
#  'date': datetime.datetime(2024, 6, 20, 14, 0),
#  'title': "Anthropic's rivalry with OpenAI heats up with its claim new Claude AI surpasses GPT-4o",
#  'body': 'Just a month after OpenAI rolled out its latest AI model, GPT-4o, today its rival Anthropic—famously founded by breakaway OpenAI researchers in 2021—said it had developed a new model to top it.',
#  'url': 'https://www.msn.com/en-us/news/technology/anthropic-s-rivalry-with-openai-heats-up-with-its-claim-new-claude-ai-surpasses-gpt-4o/ar-BB1oApe1',
#  'image': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/BB1oAbpV.img?w=2048&h=1366&m=4&q=88',
#  'source': 'Fortune on MSN.com',
#  'found_at': datetime.datetime(2024, 6, 26, 9, 51, 56, 553000)}

# %% [markdown]
# # Add vectors to existing data
#
# In this section, we identify all records in the dataset that lack embeddings. We then generate all the embeddings for these records and proceed to update each record accordingly.

# %%
EMBEDDING_MODEL = "text-embedding-3-small"
DIMENSIONS = 1536

# %%
from openai import OpenAI

Embedding = list[float]

client = OpenAI()


def get_embeddings_batch(texts: list[str], dimensions: int) -> list[Embedding]:
    assert len(texts) <= 2048, "The number of texts should be less than 2048"

    response = client.embeddings.create(
        input=texts, model=EMBEDDING_MODEL, dimensions=dimensions
    )

    return [x.embedding for x in response.data]


def get_embedding(text: str, dimensions: int) -> Embedding:
    return get_embeddings_batch([text], dimensions)[0]

# %%
from typing import List, Dict, Any
from pymongo.operations import UpdateOne
from openai import OpenAI

from openai import OpenAI

client = OpenAI()

# Define batch size
BATCH_SIZE: int = 1000


def process_batch(batch: List[Dict[str, Any]]) -> None:
    # Extract text from documents (combining title and body)
    texts: List[str] = [f"{doc['title']} - {doc['body']}" for doc in batch]

    # Generate embeddings
    embeddings: List[Embedding] = get_embeddings_batch(texts, dimensions=DIMENSIONS)

    # Prepare bulk update operations
    bulk_operations: List[UpdateOne] = []
    for doc, embedding in zip(batch, embeddings):
        bulk_operations.append(
            UpdateOne(
                {"_id": doc["_id"]}, {"$set": {"title_body_embedding": embedding}}
            )
        )

    # Execute bulk update
    if bulk_operations:
        collection.bulk_write(bulk_operations)


def update_embeddings(limit: int | None = None) -> None:
    # Query for documents without title_body_embedding
    query = {
        "$or": [
            {"title_body_embedding": {"$exists": False}},
            {"title_body_embedding": None},
            {"title_body_embedding": []},
        ]
    }

    # Get total number of documents to update, respecting the limit
    total_docs: int = (
        min(collection.count_documents(query), limit)
        if limit
        else collection.count_documents(query)
    )
    processed_docs: int = 0

    print(f"Total documents to process: {total_docs}")

    while processed_docs < total_docs:
        # Calculate remaining documents to process
        remaining_docs = total_docs - processed_docs
        current_batch_size = min(BATCH_SIZE, remaining_docs)

        # Fetch a batch of documents
        cursor = collection.find(query, {"title": 1, "body": 1}).limit(
            current_batch_size
        )
        batch: List[Dict[str, Any]] = list(cursor)

        if not batch:
            break

        # Process the batch
        process_batch(batch)

        processed_docs += len(batch)
        print(f"Processed {processed_docs}/{total_docs} documents")


print(
    f"Updating embeddings for {DB_NAME}.{COLLECTION_NAME} with dimensions={DIMENSIONS}..."
)

update_embeddings()
# Out:
# Updating embeddings for blogdb.ai_news with dimensions=1536...
# Total documents to process: 3167
# Processed 1000/3167 documents
# Processed 2000/3167 documents
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[5], line 79
#      72         print(f"Processed {processed_docs}/{total_docs} documents")
#      75 print(
#      76     f"Updating embeddings for {DB_NAME}.{COLLECTION_NAME} with dimensions={DIMENSIONS}..."
#      77 )
# ---> 79 update_embeddings()
#
# Cell In[5], line 69, in update_embeddings(limit)
#      66     break
#      68 # Process the batch
# ---> 69 process_batch(batch)
#      71 processed_docs += len(batch)
#      72 print(f"Processed {processed_docs}/{total_docs} documents")
#
# Cell In[5], line 31, in process_batch(batch)
#      29 # Execute bulk update
#      30 if bulk_operations:
# ---> 31     collection.bulk_write(bulk_operations)
#
# ...

# %%
def remove_all_embeddings():
    # prompt for confirmation
    confirmation = input("Are you sure you want to remove all embeddings? (yes/no): ")
    if confirmation.lower() != "yes":
        print("No embeddings have been removed")
        return
    collection.update_many({}, {"$unset": {EMBEDDING_FIELD: ""}})
    print("All embeddings have been removed")


remove_all_embeddings()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[6], line 10
#       7     collection.update_many({}, {"$unset": {EMBEDDING_FIELD: ""}})
#       8     print("All embeddings have been removed")
# ---> 10 remove_all_embeddings()
#
# Cell In[6], line 7, in remove_all_embeddings()
#       5     print("No embeddings have been removed")
#       6     return
# ----> 7 collection.update_many({}, {"$unset": {EMBEDDING_FIELD: ""}})
#       8 print("All embeddings have been removed")
#
# File c:\Users\samue\AppData\Local\pypoetry\Cache\virtualenvs\blog-db-crR3mef3-py3.12\Lib\site-packages\pymongo\collection.py:1177, in Collection.update_many(self, filter, update, upsert, array_filters, bypass_document_validation, collation, hint, session, let, comment)
#    1173 common.validate_list_or_none("array_filters", array_filters)
#    1175 write_concern = self._write_concern_for(session)
# ...

# %% [markdown]
# # Rag

# %%
QUERY = "La france se préparer de nouvelles élections"

query_embedding = get_embedding(QUERY, dimensions=DIMENSIONS)

LIMIT = 10
NUM_CANDIDATES = 20 * LIMIT  # should be between 10 and 20 times the limit

# Sample vector search pipeline
pipeline = [
    {
        "$vectorSearch": {
            "index": VECTOR_INDEX_NAME,
            "queryVector": query_embedding,
            "path": EMBEDDING_FIELD,
            "numCandidates": 100,
            "limit": 5,
        }
    },
    {
        "$project": {
            "_id": 0,
            "title": 1,
            "date": 1,
            "url": 1,
            "body": 1,
            "score": {"$meta": "vectorSearchScore"},
        }
    },
]

results = collection.aggregate(pipeline)

for i in results:
    print(
        f"Title: {i['title']}\nDate: {i['date']} \nURL: {i['url']}\nScore: {i['score']}\n\n{i['body']}\n\n\n\n"
    )
# Out:
# Title: Francia, elezioni legislative anticipate: oltre 410mila francesi residenti all'estero hanno già votato online
# Date: 2024-06-27 13:54:00
# URL: https://www.tpi.it/esteri/francia-elezioni-legislative-410mila-francesi-residenti-estero-voto-online-202406271112184/
# Score: 0.7279719710350037
#
# Tale affluenza, secondo il governo transalpino, costituisce un record rispetto ai 250 mila votanti all'estero online delle ultime consultazioni. Durante le ultime elezioni legislative del 2022, questo metodo di voto era stato il più utilizzato dai ...
#
#
#
#
# Title: Busy election season sees voters heading to the polls from Mongolia to Iran to Britain in coming days
# Date: 2024-06-27 15:40:00
# URL: https://www.pbs.org/newshour/world/busy-election-season-sees-voters-heading-to-the-polls-from-mongolia-to-iran-to-britain-in-coming-days
# Score: 0.7010672688484192
#
# ...

# %% [markdown]
# # MongoDB & Langchain

# %%
# add this import for running in jupyter notebook
import nest_asyncio

nest_asyncio.apply()

# %%
from langchain_community.document_loaders import NewsURLLoader


urls = [
    "https://www.nbcconnecticut.com/news/national-international/britain-looks-to-upstage-france-with-play-for-worlds-third-major-ai-hub-after-u-s-china/3321951/",
    "https://www.nbclosangeles.com/news/national-international/britain-looks-to-upstage-france-with-play-for-worlds-third-major-ai-hub-after-u-s-china/3445212/",
    "https://es-us.finanzas.yahoo.com/news/france-leads-pack-generative-ai-154418992.html",
    "https://uk.finance.yahoo.com/news/france-leads-pack-generative-ai-234317765.html",
    "https://www.msn.com/en-us/money/economy/macron-runs-france-like-a-ceo-his-customers-aren-t-happy/ar-BB1p2d0z",
    "https://au.news.yahoo.com/france-leads-pack-generative-ai-234317765.html",
    "https://www.livemint.com/politics/news/macron-runs-france-like-a-ceo-his-customers-aren-t-happy-11719550973368.html",
]


loader = NewsURLLoader(urls=urls)
data = loader.load()
print("First article: ", data[0].page_content)
# Out:
# First article:  At the London Tech Week conference in the Olympia events venue earlier this month, tech executives from around the world touted London and the U.K. as a place to invest.
#
# Last week, Salesforce opened its first flagship AI center in London, as part of a five-year $4 billion investment commitment to the U.K. announced last year.
#
# London is facing heated rivalry from France for the title of European AI leader.
#
# Some critics have poured doubt on Britain's ability to stay ahead as Europe's leading AI hub.
#
# LONDON — Global tech entrepreneurs and investors are talking up the U.K.'s potential to become an artificial intelligence powerhouse rivaling the likes of the U.S. and China.
#
# But key challenges face the country as it looks to become the world's third-biggest AI hub.
#
# At the London Tech Week conference in the Olympia events venue earlier this month, tech executives from around the world touted London and the U.K. as a place to invest.
#
# ...

# %% [markdown]
# # QA

# %%
# %pip install -qU langchain-mongodb
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import OpenAIEmbeddings

from langchain_mongodb.vectorstores import MongoDBAtlasVectorSearch


embeddings = OpenAIEmbeddings(
    model=EMBEDDING_MODEL,
)

vector_search = MongoDBAtlasVectorSearch(
    collection,
    embeddings,
    index_name=VECTOR_INDEX_NAME,
    embedding_key=EMBEDDING_FIELD,
    relevance_score_fn="cosine",
    text_key="title",
)

vector_search.similarity_search("France")
# Out:
# [Document(page_content='France votes in snap polls as far-right eyes historic win', metadata={'_id': {'$oid': '668260f8bd1ff5839d2dd2eb'}, 'date': datetime.datetime(2024, 6, 30, 15, 0), 'body': "French people vote on Sunday in high-stakes snap parliamentary elections which could alter France's trajectory and see the far-right party of Marine Le Pen take power in a historic first. With Russia's war against Ukraine in its third year and energy and ...", 'url': 'https://www.msn.com/en-us/news/world/france-votes-in-snap-polls-as-far-right-eyes-historic-win/ar-BB1p8tms', 'image': 'https://japantoday-asset.scdn3.secure.raxcdn.com/img/store/07/58/47930e500799a45ca55ca174d89c8e98ddd8/075847930e500799a45ca55ca174d89c8e98ddd8/_w1700.jpg', 'source': 'AFP on MSN.com', 'found_at': datetime.datetime(2024, 7, 1, 7, 46, 24, 657000)}),
# ...

# %% [markdown]
# ## Retreival

# %%
TOP_K = 10


retriever = vector_search.as_retriever(
    search_type="similarity",
    search_kwargs={"k": TOP_K},
)

retriever.invoke("AI is a hoax")
# Out:
# [Document(page_content='AI is sabotaging the energy transition', metadata={'_id': {'$oid': '667d34985827b887eda4cca7'}, 'date': datetime.datetime(2024, 6, 24, 16, 7), 'body': 'ARTIFICIAL intelligence, or AI, is the currently popular manifestation of the problematic belief of humans that if we can do a thing, we must do a thing. For every supposed benefit hailed by AI advocates,', 'url': 'https://www.msn.com/en-ph/news/opinion/ai-is-sabotaging-the-energy-transition/ar-BB1oNY6B', 'image': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/BB1oNVzR.img?w=1200&h=630&m=4&q=99', 'source': 'The Manila Times on MSN.com', 'found_at': datetime.datetime(2024, 6, 27, 9, 33, 27, 246000)}),
# ...

# %% [markdown]
# ### Prompting

# %%
from langchain_anthropic import ChatAnthropic
from langchain_openai import ChatOpenAI


gpt4o = ChatOpenAI(model_name="gpt-4o")  # type:ignore # Arguments missing for parameters "timeout", "api_key"PylancereportCallIssue
haiku = ChatAnthropic(model_name="claude-3-haiku-20240307")  # type: ignore
sonnet3_5 = ChatAnthropic(model_name="claude-3-5-sonnet-20240620")  # type: ignore


llm = sonnet3_5

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    "You are an assistant for question-answering about AI news. "
    "Use the following pieces of retrieved news articles to answer the question. "
    "If you don't know the answer, just say that you don't know. "
    "Question : {input}\n"
    "Context : \n{context}\n\n"
    "Answer:"
)

document_prompt = PromptTemplate.from_template(
    "{page_content} - (Published on {date})\n{body}"
)

stuff_documents_chain = create_stuff_documents_chain(
    llm=llm,
    prompt=prompt,
    document_prompt=document_prompt,
    document_separator="\n\n",
)


# stuff_documents_chain.invoke({"context": retriever.invoke("Mistral funding"), "question": 'Is mistral rich ?'})
# 'Based on the news articles provided, it appears that Mistral AI is a well-funded and valuable AI company, but the articles do not contain any information about whether the company or its founders are considered "rich". The articles focus on Mistral AI\'s recent $600 million funding round and the resulting $6 billion valuation, but do not make any claims about the personal wealth of the company\'s leadership or employees. Therefore, I do not have enough information to definitively answer whether Mistral is "rich". The news articles simply don\'t address that specific question.'


rag_chain = create_retrieval_chain(retriever, stuff_documents_chain)

rag_chain.invoke({"input": "How France elections might impact AI industry ?"})
# Out:
# {'input': 'How France elections might impact AI industry ?',
#  'context': [Document(page_content="Inside Europe's tech hubs: France's AI push puts it on the rise", metadata={'_id': {'$oid': '66825e4fbd1ff5839d2dbf88'}, 'date': datetime.datetime(2024, 6, 27, 0, 1), 'body': "France has looked to position itself as Europe's leading artificial intelligence hub, with high-profile companies like Mistral AI and H getting large amounts of funding. French generative AI ...", 'url': 'https://www.nbcchicago.com/news/national-international/inside-europes-tech-hubs-frances-ai-push-puts-it-on-the-rise/3474784/', 'image': '', 'source': 'NBC Chicago', 'found_at': datetime.datetime(2024, 7, 1, 7, 35, 35, 387000)}),
# ...

# %%
title = "France leads the pack for generative AI funding in Europe"

results = collection.find({"title": title})

for i in results:
    print(
        f"Title: {i['title']}\nDate: {i['date']} \nURL: {i['url']}\n\n{i['body']}\n\n\n\n"
    )
# Out:
# Title: France leads the pack for generative AI funding in Europe
# Date: 2024-06-21 00:39:00
# URL: https://techcrunch.com/2024/06/19/france-leads-the-pack-for-generative-ai-funding-in-europe-london-has-3x-the-number-of-genai-startups/
#
# Like it or hate it, artificial intelligence — especially generative AI — is the technology story of 2024. OpenAI, with its rollouts of viral services like
#
#
#
#
# Title: France leads the pack for generative AI funding in Europe
# Date: 2024-06-27 15:44:00
# URL: https://www.yahoo.com/entertainment/france-leads-pack-generative-ai-234317765.html
#
# Other notable AI startup activity in Paris includes Hugging Face, the open source repository for machine learning models, which raised $235 million in August 2023, and a new research-focused organization called Kyutai, which is armed with hundreds of ...
#
#
#
#
# Title: France leads the pack for generative AI funding in Europe
# Date: 2024-06-27 15:44:00
# ...
